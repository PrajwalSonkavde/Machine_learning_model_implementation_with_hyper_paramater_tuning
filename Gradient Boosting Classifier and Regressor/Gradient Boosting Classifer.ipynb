# %%
import pandas as pd

# %%
df = pd.read_csv("mlbootcamp5_train.csv")

# %%
df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %% [markdown]
# ## EDA

# %%
df.isnull().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           70000 non-null  int64
#  1   age          70000 non-null  int64
#  2   gender       70000 non-null  int64
#  3   height       70000 non-null  int64
#  4   weight       70000 non-null  float64
#  5   ap_hi        70000 non-null  int64
#  6   ap_lo        70000 non-null  int64
#  7   cholesterol  70000 non-null  int64
#  8   gluc         70000 non-null  int64
#  9   smoke        70000 non-null  int64
#  10  alco         70000 non-null  int64
#  11  active       70000 non-null  int64
#  12  cardio       70000 non-null  int64
# dtypes: float64(1), int64(12)
# memory usage: 6.9 MB

# %% [markdown]
# ## Spliting the data

# %%
from sklearn.model_selection import train_test_split

# %%
x= df.drop(['smoke'],axis=1)
y=df['smoke']
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape
# Out:
# (56000, 12)

# %%
y_train.shape
# Out:
# (56000,)

# %%
x_test.shape
# Out:
# (14000, 12)

# %%
y_test.shape
# Out:
# (14000,)

# %% [markdown]
# ## Gradient Boosting Classifer

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score

# %%
gs_gb = GradientBoostingClassifier()
gs_gb.fit(x_train , y_train)
pred = gs_gb.predict(x_test)
print(accuracy_score(pred , y_test))
# Out:
# 0.9226428571428571

# %% [markdown]
# ## Gradient boosting Classifier hyper parameter tuning using GridSearchCv

# %% [markdown]
# loss{‘log_loss’, ‘deviance’, ‘exponential’}, default=’log_loss’ : The loss function to be optimized. ‘log_loss’ refers to binomial and multinomial deviance, the same as used in logistic regression. It is a good choice for classification with probabilistic outputs. For loss ‘exponential’, gradient boosting recovers the AdaBoost algorithm.
#
# learning_rate float, default=0.1 : Learning rate shrinks the contribution of each tree by learning_rate. There is a trade-off between learning_rate and n_estimators. Values must be in the range [0.0, inf).
#
# n_estimators int, default=100 : The number of boosting stages to perform. Gradient boosting is fairly robust to over-fitting so a large number usually results in better performance. Values must be in the range [1, inf).
#
# subsample float, default=1.0 : The fraction of samples to be used for fitting the individual base learners. If smaller than 1.0 this results in Stochastic Gradient Boosting. subsample interacts with the parameter n_estimators. Choosing subsample < 1.0 leads to a reduction of variance and an increase in bias. Values must be in the range (0.0, 1.0].
#
# criterion{‘friedman_mse’, ‘squared_error’}, default=’friedman_mse’ : The function to measure the quality of a split. Supported criteria are ‘friedman_mse’ for the mean squared error with improvement score by Friedman, ‘squared_error’ for mean squared error. The default value of ‘friedman_mse’ is generally the best as it can provide a better approximation in some cases.
#
# min_samples_split int or float, default=2 : The minimum number of samples required to split an internal node,If int, values must be in the range [2, inf] ,If float, values must be in the range (0.0, 1.0] and min_samples_split will be ceil(min_samples_split * n_samples).
#
# min_samples_leafint or float, default=1 : The minimum number of samples required to be at a leaf node. A split point at any depth will only be considered if it leaves at least min_samples_leaf training samples in each of the left and right branches. This may have the effect of smoothing the model, especially in regression,If int, values must be in the range [1, inf],If float, values must be in the range (0.0, 1.0) and min_samples_leaf will be ceil(min_samples_leaf * n_samples).
#
# min_weight_fraction_leaffloat, default=0.0
# The minimum weighted fraction of the sum total of weights (of all the input samples) required to be at a leaf node. Samples have equal weight when sample_weight is not provided. Values must be in the range [0.0, 0.5].
#
# max_depthint or None, default=3 : Maximum depth of the individual regression estimators. The maximum depth limits the number of nodes in the tree. Tune this parameter for best performance; the best value depends on the interaction of the input variables. If None, then nodes are expanded until all leaves are pure or until all leaves contain less than min_samples_split samples. If int, values must be in the range [1, inf).
#
# min_impurity_decrease float, default=0.0 : A node will be split if this split induces a decrease of the impurity greater than or equal to this value. Values must be in the range [0.0, inf).
#
# The weighted impurity decrease equation is the following:
#
# N_t / N * (impurity - N_t_R / N_t * right_impurity
#                     - N_t_L / N_t * left_impurity)
# where N is the total number of samples, N_t is the number of samples at the current node, N_t_L is the number of samples in the left child, and N_t_R is the number of samples in the right child.
#
# N, N_t, N_t_R and N_t_L all refer to the weighted sum, if sample_weight is passed.
#
# New in version 0.19.
#
# init : estimator or ‘zero’, default=None : An estimator object that is used to compute the initial predictions. init has to provide fit and predict_proba. If ‘zero’, the initial raw predictions are set to zero. By default, a DummyEstimator predicting the classes priors is used.
#
# random_state int, RandomState instance or None, default=None : Controls the random seed given to each Tree estimator at each boosting iteration. In addition, it controls the random permutation of the features at each split (see Notes for more details). It also controls the random splitting of the training data to obtain a validation set if n_iter_no_change is not None. Pass an int for reproducible output across multiple function calls. See Glossary.
#
# max_features{‘auto’, ‘sqrt’, ‘log2’}, int or float, default=None : The number of features to consider when looking for the best split, If int, values must be in the range [1, inf] , If float, values must be in the range (0.0, 1.0] and the features considered at each split will be max(1, int(max_features * n_features_in_)),If ‘auto’, then max_features=sqrt(n_features), If ‘sqrt’, then max_features=sqrt(n_features),If ‘log2’, then max_features=log2(n_features),If None, then max_features=n_features. Choosing max_features < n_features leads to a reduction of variance and an increase in bias. Note: the search for a split does not stop until at least one valid partition of the node samples is found, even if it requires to effectively inspect more than max_features features.
#
# verbose int, default=0 : Enable verbose output. If 1 then it prints progress and performance once in a while (the more trees the lower the frequency). If greater than 1 then it prints progress and performance for every tree. Values must be in the range [0, inf).
#
# max_leaf_nodes int, default=None : Grow trees with max_leaf_nodes in best-first fashion. Best nodes are defined as relative reduction in impurity. Values must be in the range [2, inf). If None, then unlimited number of leaf nodes.
#
# warm_start bool, default=False : When set to True, reuse the solution of the previous call to fit and add more estimators to the ensemble, otherwise, just erase the previous solution. See the Glossary.
#
# validation_fraction float, default=0.1 : The proportion of training data to set aside as validation set for early stopping. Values must be in the range (0.0, 1.0). Only used if n_iter_no_change is set to an integer.
#
# n_iter_no_change int, default=None : n_iter_no_change is used to decide if early stopping will be used to terminate training when validation score is not improving. By default it is set to None to disable early stopping. If set to a number, it will set aside validation_fraction size of the training data as validation and terminate training when validation score is not improving in all of the previous n_iter_no_change numbers of iterations. The split is stratified. Values must be in the range [1, inf]
#
# tol float, default=1e-4 : Tolerance for the early stopping. When the loss is not improving by at least tol for n_iter_no_change iterations (if set to a number), the training stops. Values must be in the range [0.0, inf].
#
# ccp_alphanon-negative float, default=0.0 : Complexity parameter used for Minimal Cost-Complexity Pruning. The subtree with the largest cost complexity that is smaller than ccp_alpha will be chosen. By default, no pruning is performed. Values must be in the range [0.0, inf]. See Minimal Cost-Complexity Pruning for details.

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier

# %%
params ={
    'loss' : ['log_loss', 'deviance', 'exponential'],
    'learning_rate' :[0.0001,0.001 , 0.01 , 0.1,1,2],
    'criterion' : ['friedman_mse', 'squared_error'],
    'ccp_alpha' : [0.0001,0.001,0.01,0.1,1]
}

# %%
gb = GradientBoostingClassifier()
gs_gb = GridSearchCV(gb , param_grid =params,cv=3 , scoring='accuracy',verbose =2)

# %%
gs_gb.fit(x_train , y_train)
# Out:
# Fitting 3 folds for each of 180 candidates, totalling 540 fits
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=0.0001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=0.0001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=0.0001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=0.0001, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=0.0001, loss=deviance; total time=   3.7s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=0.0001, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=0.0001, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=0.0001, loss=exponential; total time=   3.8s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=0.0001, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=0.001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=0.001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=0.001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=0.001, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=0.001, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=0.001, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=0.001, loss=exponential; total time=   3.7s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=0.001, loss=exponential; total time=   3.7s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=0.001, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=0.01, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=0.01, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=0.01, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=0.01, loss=deviance; total time=   3.7s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=0.01, loss=deviance; total time=   3.8s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=0.01, loss=deviance; total time=   4.0s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=0.01, loss=exponential; total time=   3.8s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=0.01, loss=exponential; total time=   3.7s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=0.01, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=0.1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=0.1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=0.1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=0.1, loss=deviance; total time=   3.7s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=0.1, loss=deviance; total time=   3.7s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=0.1, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=0.1, loss=exponential; total time=   3.8s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=0.1, loss=exponential; total time=   3.7s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=0.1, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=1, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=1, loss=deviance; total time=   3.7s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=1, loss=deviance; total time=   3.7s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=1, loss=exponential; total time=   3.7s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=1, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=1, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=2, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=2, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=2, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=2, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=2, loss=deviance; total time=   3.7s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=2, loss=deviance; total time=   3.9s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=2, loss=exponential; total time=   3.7s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=2, loss=exponential; total time=   3.7s
# [CV] END ccp_alpha=0.0001, criterion=friedman_mse, learning_rate=2, loss=exponential; total time=   3.7s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=0.0001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=0.0001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=0.0001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=0.0001, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=0.0001, loss=deviance; total time=   3.7s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=0.0001, loss=deviance; total time=   3.7s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=0.0001, loss=exponential; total time=   3.7s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=0.0001, loss=exponential; total time=   3.7s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=0.0001, loss=exponential; total time=   3.7s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=0.001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=0.001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=0.001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=0.001, loss=deviance; total time=   3.7s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=0.001, loss=deviance; total time=   3.7s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=0.001, loss=deviance; total time=   3.7s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=0.001, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=0.001, loss=exponential; total time=   3.7s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=0.001, loss=exponential; total time=   3.7s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=0.01, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=0.01, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=0.01, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=0.01, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=0.01, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=0.01, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=0.01, loss=exponential; total time=   3.7s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=0.01, loss=exponential; total time=   3.7s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=0.01, loss=exponential; total time=   3.7s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=0.1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=0.1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=0.1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=0.1, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=0.1, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=0.1, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=0.1, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=0.1, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=0.1, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=1, loss=deviance; total time=   3.7s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=1, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=1, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=1, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=1, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=1, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=2, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=2, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=2, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=2, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=2, loss=deviance; total time=   3.7s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=2, loss=deviance; total time=   3.7s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=2, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=2, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.0001, criterion=squared_error, learning_rate=2, loss=exponential; total time=   3.7s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=0.0001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=0.0001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=0.0001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=0.0001, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=0.0001, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=0.0001, loss=deviance; total time=   3.5s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=0.0001, loss=exponential; total time=   3.5s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=0.0001, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=0.0001, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=0.001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=0.001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=0.001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=0.001, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=0.001, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=0.001, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=0.001, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=0.001, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=0.001, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=0.01, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=0.01, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=0.01, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=0.01, loss=deviance; total time=   3.5s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=0.01, loss=deviance; total time=   3.5s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=0.01, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=0.01, loss=exponential; total time=   3.5s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=0.01, loss=exponential; total time=   3.5s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=0.01, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=0.1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=0.1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=0.1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=0.1, loss=deviance; total time=   3.5s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=0.1, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=0.1, loss=deviance; total time=   3.5s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=0.1, loss=exponential; total time=   3.5s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=0.1, loss=exponential; total time=   3.5s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=0.1, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=1, loss=deviance; total time=   3.5s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=1, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=1, loss=deviance; total time=   3.5s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=1, loss=exponential; total time=   3.5s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=1, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=1, loss=exponential; total time=   3.5s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=2, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=2, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=2, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=2, loss=deviance; total time=   3.7s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=2, loss=deviance; total time=   3.7s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=2, loss=deviance; total time=   3.8s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=2, loss=exponential; total time=   3.7s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=2, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.001, criterion=friedman_mse, learning_rate=2, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=0.0001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=0.0001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=0.0001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=0.0001, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=0.0001, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=0.0001, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=0.0001, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=0.0001, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=0.0001, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=0.001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=0.001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=0.001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=0.001, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=0.001, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=0.001, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=0.001, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=0.001, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=0.001, loss=exponential; total time=   3.7s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=0.01, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=0.01, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=0.01, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=0.01, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=0.01, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=0.01, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=0.01, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=0.01, loss=exponential; total time=   3.5s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=0.01, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=0.1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=0.1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=0.1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=0.1, loss=deviance; total time=   3.5s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=0.1, loss=deviance; total time=   3.5s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=0.1, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=0.1, loss=exponential; total time=   3.5s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=0.1, loss=exponential; total time=   3.5s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=0.1, loss=exponential; total time=   3.5s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=1, loss=deviance; total time=   3.5s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=1, loss=deviance; total time=   3.5s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=1, loss=deviance; total time=   3.5s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=1, loss=exponential; total time=   3.5s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=1, loss=exponential; total time=   3.5s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=1, loss=exponential; total time=   3.5s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=2, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=2, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=2, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=2, loss=deviance; total time=   3.7s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=2, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=2, loss=deviance; total time=   3.7s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=2, loss=exponential; total time=   3.5s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=2, loss=exponential; total time=   3.5s
# [CV] END ccp_alpha=0.001, criterion=squared_error, learning_rate=2, loss=exponential; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.0001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.0001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.0001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.0001, loss=deviance; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.0001, loss=deviance; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.0001, loss=deviance; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.0001, loss=exponential; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.0001, loss=exponential; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.0001, loss=exponential; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.001, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.001, loss=deviance; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.001, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.001, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.001, loss=exponential; total time=   3.7s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.001, loss=exponential; total time=   3.8s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.01, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.01, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.01, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.01, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.01, loss=deviance; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.01, loss=deviance; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.01, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.01, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.01, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.1, loss=deviance; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.1, loss=deviance; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.1, loss=deviance; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.1, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.1, loss=exponential; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=0.1, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=1, loss=deviance; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=1, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=1, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=1, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=1, loss=exponential; total time=   3.9s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=1, loss=exponential; total time=   3.7s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=2, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=2, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=2, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=2, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=2, loss=deviance; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=2, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=2, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=2, loss=exponential; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=friedman_mse, learning_rate=2, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=0.0001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=0.0001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=0.0001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=0.0001, loss=deviance; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=0.0001, loss=deviance; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=0.0001, loss=deviance; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=0.0001, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=0.0001, loss=exponential; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=0.0001, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=0.001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=0.001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=0.001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=0.001, loss=deviance; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=0.001, loss=deviance; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=0.001, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=0.001, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=0.001, loss=exponential; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=0.001, loss=exponential; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=0.01, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=0.01, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=0.01, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=0.01, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=0.01, loss=deviance; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=0.01, loss=deviance; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=0.01, loss=exponential; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=0.01, loss=exponential; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=0.01, loss=exponential; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=0.1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=0.1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=0.1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=0.1, loss=deviance; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=0.1, loss=deviance; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=0.1, loss=deviance; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=0.1, loss=exponential; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=0.1, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=0.1, loss=exponential; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=1, loss=deviance; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=1, loss=deviance; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=1, loss=deviance; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=1, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=1, loss=exponential; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=1, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=2, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=2, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=2, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=2, loss=deviance; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=2, loss=deviance; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=2, loss=deviance; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=2, loss=exponential; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=2, loss=exponential; total time=   3.5s
# [CV] END ccp_alpha=0.01, criterion=squared_error, learning_rate=2, loss=exponential; total time=   3.5s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.0001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.0001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.0001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.0001, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.0001, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.0001, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.0001, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.0001, loss=exponential; total time=   9.9s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.0001, loss=exponential; total time=   3.8s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.001, loss=deviance; total time=   3.8s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.001, loss=deviance; total time=   3.9s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.001, loss=deviance; total time=   4.0s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.001, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.001, loss=exponential; total time=   3.8s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.001, loss=exponential; total time=   3.7s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.01, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.01, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.01, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.01, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.01, loss=deviance; total time=   3.7s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.01, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.01, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.01, loss=exponential; total time=   3.7s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.01, loss=exponential; total time=   3.8s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.1, loss=deviance; total time=   3.8s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.1, loss=deviance; total time=   3.8s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.1, loss=deviance; total time=   3.9s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.1, loss=exponential; total time=   3.8s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.1, loss=exponential; total time=   3.8s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=0.1, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=1, loss=deviance; total time=   3.7s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=1, loss=deviance; total time=   3.5s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=1, loss=deviance; total time=   3.7s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=1, loss=exponential; total time=   3.7s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=1, loss=exponential; total time=   4.6s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=1, loss=exponential; total time=   4.8s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=2, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=2, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=2, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=2, loss=deviance; total time=   4.6s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=2, loss=deviance; total time=   4.4s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=2, loss=deviance; total time=   4.2s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=2, loss=exponential; total time=   4.4s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=2, loss=exponential; total time=   4.2s
# [CV] END ccp_alpha=0.1, criterion=friedman_mse, learning_rate=2, loss=exponential; total time=   4.2s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=0.0001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=0.0001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=0.0001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=0.0001, loss=deviance; total time=   4.3s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=0.0001, loss=deviance; total time=   4.7s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=0.0001, loss=deviance; total time=   4.7s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=0.0001, loss=exponential; total time=   4.3s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=0.0001, loss=exponential; total time=   4.2s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=0.0001, loss=exponential; total time=   4.2s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=0.001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=0.001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=0.001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=0.001, loss=deviance; total time=   4.1s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=0.001, loss=deviance; total time=   4.3s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=0.001, loss=deviance; total time=   4.9s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=0.001, loss=exponential; total time=   5.0s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=0.001, loss=exponential; total time=   5.1s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=0.001, loss=exponential; total time=   4.7s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=0.01, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=0.01, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=0.01, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=0.01, loss=deviance; total time=   4.8s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=0.01, loss=deviance; total time=   4.8s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=0.01, loss=deviance; total time=   4.6s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=0.01, loss=exponential; total time=   4.7s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=0.01, loss=exponential; total time=   4.7s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=0.01, loss=exponential; total time=   5.3s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=0.1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=0.1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=0.1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=0.1, loss=deviance; total time=   5.0s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=0.1, loss=deviance; total time=   4.0s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=0.1, loss=deviance; total time=   3.8s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=0.1, loss=exponential; total time=   3.7s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=0.1, loss=exponential; total time=   3.7s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=0.1, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=1, loss=deviance; total time=   3.9s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=1, loss=deviance; total time=   3.7s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=1, loss=deviance; total time=   3.7s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=1, loss=exponential; total time=   3.8s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=1, loss=exponential; total time=   3.9s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=1, loss=exponential; total time=   3.7s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=2, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=2, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=2, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=2, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=2, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=2, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=2, loss=exponential; total time=   3.8s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=2, loss=exponential; total time=   3.7s
# [CV] END ccp_alpha=0.1, criterion=squared_error, learning_rate=2, loss=exponential; total time=   3.7s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=0.0001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=0.0001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=0.0001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=0.0001, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=0.0001, loss=deviance; total time=   3.7s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=0.0001, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=0.0001, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=0.0001, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=0.0001, loss=exponential; total time=   3.7s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=0.001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=0.001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=0.001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=0.001, loss=deviance; total time=   3.8s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=0.001, loss=deviance; total time=   3.7s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=0.001, loss=deviance; total time=   3.7s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=0.001, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=0.001, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=0.001, loss=exponential; total time=   3.7s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=0.01, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=0.01, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=0.01, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=0.01, loss=deviance; total time=   3.7s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=0.01, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=0.01, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=0.01, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=0.01, loss=exponential; total time=   3.9s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=0.01, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=0.1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=0.1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=0.1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=0.1, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=0.1, loss=deviance; total time=   3.7s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=0.1, loss=deviance; total time=   3.7s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=0.1, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=0.1, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=0.1, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=1, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=1, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=1, loss=deviance; total time=   3.6s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=1, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=1, loss=exponential; total time=   3.7s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=1, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=2, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=2, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=2, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=2, loss=deviance; total time=   3.9s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=2, loss=deviance; total time=   3.7s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=2, loss=deviance; total time=   3.7s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=2, loss=exponential; total time=   3.8s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=2, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=1, criterion=friedman_mse, learning_rate=2, loss=exponential; total time=   3.7s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=0.0001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=0.0001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=0.0001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=0.0001, loss=deviance; total time=   3.7s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=0.0001, loss=deviance; total time=   3.7s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=0.0001, loss=deviance; total time=   3.7s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=0.0001, loss=exponential; total time=   3.7s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=0.0001, loss=exponential; total time=   3.7s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=0.0001, loss=exponential; total time=   3.9s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=0.001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=0.001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=0.001, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=0.001, loss=deviance; total time=   3.8s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=0.001, loss=deviance; total time=   3.8s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=0.001, loss=deviance; total time=   3.9s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=0.001, loss=exponential; total time=   3.6s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=0.001, loss=exponential; total time=   4.0s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=0.001, loss=exponential; total time=   3.8s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=0.01, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=0.01, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=0.01, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=0.01, loss=deviance; total time=   3.7s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=0.01, loss=deviance; total time=   4.2s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=0.01, loss=deviance; total time=   4.5s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=0.01, loss=exponential; total time=   4.3s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=0.01, loss=exponential; total time=   4.3s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=0.01, loss=exponential; total time=   4.1s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=0.1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=0.1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=0.1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=0.1, loss=deviance; total time=   4.3s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=0.1, loss=deviance; total time=   4.2s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=0.1, loss=deviance; total time=   4.3s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=0.1, loss=exponential; total time=   4.1s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=0.1, loss=exponential; total time=   4.2s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=0.1, loss=exponential; total time=   4.1s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=1, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=1, loss=deviance; total time=   4.2s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=1, loss=deviance; total time=   4.4s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=1, loss=deviance; total time=   5.2s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=1, loss=exponential; total time=   5.0s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=1, loss=exponential; total time=   4.8s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=1, loss=exponential; total time=   4.2s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=2, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=2, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=2, loss=log_loss; total time=   0.0s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=2, loss=deviance; total time=   4.1s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=2, loss=deviance; total time=   4.2s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=2, loss=deviance; total time=   4.3s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=2, loss=exponential; total time=   4.3s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=2, loss=exponential; total time=   3.8s
# [CV] END ccp_alpha=1, criterion=squared_error, learning_rate=2, loss=exponential; total time=   3.8s
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 180 fits failed out of a total of 540.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 180 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 282, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'log_loss' not supported.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [       nan 0.91125    0.91125           nan 0.91125    0.91125
#         nan 0.91125    0.91125           nan 0.92312499 0.92316071
#         nan 0.92312499 0.92132144        nan 0.72405437 0.91601783
#         nan 0.91125    0.91125           nan 0.91125    0.91125
#         nan 0.91125    0.91125           nan 0.92312499 0.92316071
#         nan 0.92312499 0.92126787        nan 0.72405437 0.91599997
#         nan 0.91125    0.91125           nan 0.91125    0.91125
#         nan 0.91125    0.91125           nan 0.91125    0.92312499
#         nan 0.92312499 0.92310713        nan 0.84003698 0.92258926
#         nan 0.91125    0.91125           nan 0.91125    0.91125
#         nan 0.91125    0.91125           nan 0.91125    0.92312499
#         nan 0.92312499 0.92310713        nan 0.84003698 0.92258926
#         nan 0.91125    0.91125           nan 0.91125    0.91125
#         nan 0.91125    0.91125           nan 0.91125    0.91125
#         nan 0.91125    0.92312499        nan 0.91125    0.92312499
#         nan 0.91125    0.91125           nan 0.91125    0.91125
#         nan 0.91125    0.91125           nan 0.91125    0.91125
#         nan 0.91125    0.92312499        nan 0.91125    0.92312499
#         nan 0.91125    0.91125           nan 0.91125    0.91125
#         nan 0.91125    0.91125           nan 0.91125    0.91125
#         nan 0.91125    0.91125           nan 0.91125    0.91485707
#         nan 0.91125    0.91125           nan 0.91125    0.91125
#         nan 0.91125    0.91125           nan 0.91125    0.91125
#         nan 0.91125    0.91125           nan 0.91125    0.91485707
#         nan 0.91125    0.91125           nan 0.91125    0.91125
#         nan 0.91125    0.91125           nan 0.91125    0.91125
#         nan 0.91125    0.91125           nan 0.91125    0.91125
#         nan 0.91125    0.91125           nan 0.91125    0.91125
#         nan 0.91125    0.91125           nan 0.91125    0.91125
#         nan 0.91125    0.91125           nan 0.91125    0.91125   ]
#   warnings.warn(
# GridSearchCV(cv=3, estimator=GradientBoostingClassifier(),
#              param_grid={'ccp_alpha': [0.0001, 0.001, 0.01, 0.1, 1],
#                          'criterion': ['friedman_mse', 'squared_error'],
#                          'learning_rate': [0.0001, 0.001, 0.01, 0.1, 1, 2],
#                          'loss': ['log_loss', 'deviance', 'exponential']},
#              scoring='accuracy', verbose=2)

# %%
print(gs_gb.best_params_)
# Out:
# {'ccp_alpha': 0.0001, 'criterion': 'friedman_mse', 'learning_rate': 0.1, 'loss': 'exponential'}

# %%
print(gs_gb.best_score_)
# Out:
# 0.923160706902394
